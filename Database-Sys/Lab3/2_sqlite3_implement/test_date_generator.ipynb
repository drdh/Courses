# %%
import random
import string

# %%
def sd(n):
    return ''.join(random.choices(string.ascii_letters + string.digits, k=n))

def s(n):
    return ''.join(random.choices(string.ascii_letters, k=n))

def d(n):
    return ''.join(random.choices( string.digits, k=n))

def i(a,b):
    return random.randint(a,b)

def a(f,n,m):
    return [f(n) for _ in range(m)]

# %% [markdown]
# -- branch
# insert into branch (branch_name,city,asset)
# 	values ("North_Bank","North",12345);
#
# insert into branch (branch_name,city,asset)
# 	values ("South_Bank","South",23456);
#
# insert into branch (branch_name,city,asset)
# 	values ("East_Bank","East",34567);
#
# insert into branch (branch_name,city,asset)
# 	values ("West_Bank","West",45678);
#
# -- employee
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (0,"North_Bank",1,"e1","ustc","123","2019-04-25 11:25:13");
#
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (1,"North_Bank",1,"e1","ustc","123","2019-04-25 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (2,"North_Bank",1,"e2","ustc","234","2019-04-24 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (3,"North_Bank",1,"e3","ustc","234","2019-04-26 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (4,"South_Bank",4,"e4","ustc","234","2019-04-26 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (5,"South_Bank",4,"e5","ustc","234","2019-04-25 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (6,"South_Bank",4,"e6","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (7,"East_Bank",7,"e7","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (8,"East_Bank",7,"e8","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (9,"East_Bank",7,"e9","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (10,"West_Bank",10,"e10","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (11,"West_Bank",10,"e11","ustc","234","2019-04-27 11:25:13");
#
# insert into employee
# (employee_id,branch_name,manager_id,name,address,phone,start_date)
# values
# (12,"West_Bank",10,"e11","ustc","234","2019-04-27 11:25:13");

# %%
random.choice([1,2,3])
random.randint(0,2)
branch_name=["North_Bank","South_Bank","East_Bank","West_Bank"]

# %%
customer_name=["ab","cd","ef","hi","jk","lm","op","qs","tu","vw","xy"]
month=["01","02","03","04","05","06","07","08","09","10","11","12"]

# %%
#define 
employee_num=13# 0-12
customer_num=133#0-133

# %%
#customer
for i in range(0,customer_num):
    print("""
insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
values 
(%d,"c%d","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");"""%(i,i))
# Out:
# insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
# values
# (0,"c0","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");
#
# insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
# values
# (1,"c1","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");
#
# insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
# values
# (2,"c2","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");
#
# insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
# values
# (3,"c3","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");
#
# insert into customer (customer_id,name,phone,address,contact_name,contact_phone,contact_email,contact_relation)
# values
# (4,"c4","345678","ustc","ab","123456","ab@mail.ustc.edu.cn","other");
#
# ...

# %%
#responsible
for i in range(0,customer_num):
    print("""
insert into responsible (employee_id,customer_id,type)
values
(%d,%d,"%s");
"""%(random.randint(0,employee_num-1),i,random.choice(["A","B"])))
# Out:
# insert into responsible (employee_id,customer_id,type)
# values
# (6,0,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (12,1,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (8,2,"B");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (12,3,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (6,4,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (2,5,"B");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (11,6,"B");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (11,7,"B");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (1,8,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (2,9,"A");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (3,10,"B");
#
#
# insert into responsible (employee_id,customer_id,type)
# values
# (11,11,"A");
# ...

# %%
#saving_account
for i in range(customer_num):
    print("""
insert into saving_account
(Account_id,branch_name,balance,open_date,interest_rate,currency_type)
values
(%d,"%s",%d,"2019-%s-12 12:23:34",%f,"%s");
"""%(i,random.choice(branch_name),random.randint(0,100),random.choice(month),random.uniform(0,1),random.choice(["RMB","USD"])))
# Out:
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# (0,"North_Bank",17,"2019-09-12 12:23:34",0.481020,"USD");
#
#
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# (1,"North_Bank",71,"2019-06-12 12:23:34",0.096273,"RMB");
#
#
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# (2,"West_Bank",67,"2019-10-12 12:23:34",0.550384,"USD");
#
#
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# (3,"West_Bank",18,"2019-12-12 12:23:34",0.125388,"RMB");
#
#
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# (4,"East_Bank",6,"2019-01-12 12:23:34",0.433916,"RMB");
#
#
# insert into saving_account
# (Account_id,branch_name,balance,open_date,interest_rate,currency_type)
# values
# ...

# %%
#check_account
for i in range(customer_num):
    print("""
insert into check_account
(Account_id,branch_name,balance,open_date,overdraft)
values
(%d,"%s",%d,"2019-%s-12 12:23:34",%d);
"""%(i+customer_num,random.choice(branch_name),random.randint(0,100),
     random.choice(month),random.randint(100,200)))
# Out:
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (133,"West_Bank",9,"2019-06-12 12:23:34",132);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (134,"West_Bank",82,"2019-08-12 12:23:34",176);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (135,"East_Bank",15,"2019-08-12 12:23:34",156);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (136,"South_Bank",43,"2019-10-12 12:23:34",188);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (137,"North_Bank",53,"2019-06-12 12:23:34",192);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# (138,"East_Bank",37,"2019-02-12 12:23:34",104);
#
#
# insert into check_account
# (Account_id,branch_name,balance,open_date,overdraft)
# values
# ...

# %%
#depositor
for i in range(2*customer_num):
    print("""
insert into depositor
(Account_id,customer_id,access_date)
values
(%d,%d,"2019-%s-12 12:23:34");
"""%(i,customer_num-i%customer_num-1,random.choice(month)))
# Out:
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (0,132,"2019-02-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (1,131,"2019-06-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (2,130,"2019-02-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (3,129,"2019-06-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (4,128,"2019-04-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (5,127,"2019-01-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (6,126,"2019-10-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (7,125,"2019-08-12 12:23:34");
#
#
# insert into depositor
# (Account_id,customer_id,access_date)
# values
# (8,124,"2019-08-12 12:23:34");
#
#
# ...

# %%
#loan
for i in range(customer_num):
    print("""
insert into loan(loan_id,branch_name,amount)
values
(%d,"%s",%d);
"""%(i,random.choice(branch_name),random.randint(100,150)))
# Out:
# insert into loan(loan_id,branch_name,amount)
# values
# (0,"West_Bank",114);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (1,"West_Bank",128);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (2,"North_Bank",105);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (3,"West_Bank",128);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (4,"West_Bank",147);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (5,"East_Bank",127);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (6,"South_Bank",117);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (7,"West_Bank",143);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (8,"West_Bank",129);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (9,"East_Bank",111);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (10,"South_Bank",148);
#
#
# insert into loan(loan_id,branch_name,amount)
# values
# (11,"East_Bank",101);
#
# ...

# %%
#payment
for i in range(2*customer_num):
    print("""
insert into payment
(loan_id,payment_id,payment_date,amount)
values
(%d,%d,"2019-%s-12 12:23:34",%d);
"""%(i%customer_num,i,random.choice(month),random.randint(0,20)))
# Out:
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (0,0,"2019-05-12 12:23:34",12);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (1,1,"2019-07-12 12:23:34",4);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (2,2,"2019-06-12 12:23:34",20);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (3,3,"2019-03-12 12:23:34",20);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (4,4,"2019-06-12 12:23:34",4);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (5,5,"2019-06-12 12:23:34",16);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (6,6,"2019-07-12 12:23:34",11);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# (7,7,"2019-07-12 12:23:34",17);
#
#
# insert into payment
# (loan_id,payment_id,payment_date,amount)
# values
# ...

# %%
#borrow
for i in range(customer_num):
    print("""
insert into borrow(customer_id,loan_id)
values
(%d,%d);
"""%(i,customer_num-1-i))
# Out:
# insert into borrow(customer_id,loan_id)
# values
# (0,132);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (1,131);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (2,130);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (3,129);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (4,128);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (5,127);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (6,126);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (7,125);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (8,124);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (9,123);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (10,122);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (11,121);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (12,120);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (13,119);
#
#
# insert into borrow(customer_id,loan_id)
# values
# (14,118);
#
#
# ...

# %%
for i,s in enumerate([("01","03"),("04","06"),("07","09"),("10","12")]):
    print(i,s)
# Out:
# 0 ('01', '03')
# 1 ('04', '06')
# 2 ('07', '09')
# 3 ('10', '12')
