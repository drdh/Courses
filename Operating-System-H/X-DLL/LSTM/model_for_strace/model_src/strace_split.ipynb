# %%
f1=open("../data/temp_out","r")
a=f1.readlines()
b=[]
c=[]
for i in range(len(a)):
    try:
        b.append(a[i].split(" ",3)[3].split(",")[0].split("(")[1][1:-1].split("/")[1:])
        c.append(a[i].split(" ",3)[3].split(",")[0].split("(")[1][1:-1])
    except Exception as e:
        print(i,e)
# Out:
# 8 list index out of range

# %%
d=[]
for i in range(len(b)): 
    try:
        d.append(b[i][0])
    except Exception as e:
        print(i,e)
# Out:
# 22 list index out of range
# 128 list index out of range
# 138 list index out of range
# 155 list index out of range

# %%
op=[]
name=[]
f2=open("../data/trace","r")
while True:
    line=f2.readline()
    if not line:
        break
    try:
        name.append(line.split(" ",3)[3].split(",")[0].split("(")[1][1:-1].split("/")[1:])
        op.append(line.split(" ",3)[3].split(",")[0].split("(")[0])
    except Exception as e:
        pass
        #print(line,e)

# %%
len(op),len(name)
# Out:
# (1886050, 1886050)

# %%
busybox_name=[]
busybox_op=[]
for i in range(len(name)):
    try:
        if(name[i][0]=="home"):
            busybox_name.append(name[i][3:])
            busybox_op.append(op[i])
    except Exception as e:
        pass

# %%
len(busybox_name),len(busybox_op)
# Out:
# (20172, 20172)

# %%
busybox_name[56][1:]
# Out:
# ['miscutils', 'devmem.c']

# %%
core_name=[]
for i in range(len(busybox_name)):
    try:
        if(len(busybox_name[i][1:])>=2):
            core_name.append(busybox_name[i][1:])
    except Exception as e:
        pass
len(core_name)
core_name
import numpy as np

core=np.array(core_name)
core.dump("../data/trace_core")

# %%
import numpy as np

# %%
core_name=np.load("../data/trace_core")
max_len=0
position=0
for i in range(len(core_name)):
    if(6>len(core_name[i])>max_len):
        max_len=len(core_name[i])
        position=i
max_len,position
# Out:
# (5, 8817)

# %%
dir2={}
name2={}
unique2={}
for i in range(len(core_name)):
    try:
        if(len(core_name[i])==2):
            unique=core_name[i][0]+'/'+core_name[i][1]
            if unique in unique2.keys():
                unique2[unique]+=1
            else:
                unique2[unique]=1
            if core_name[i][0] in dir2.keys():
                dir2[core_name[i][0]]+=1
            else:
                dir2[core_name[i][0]]=1
            if core_name[i][1] in name2.keys():
                name2[core_name[i][1]]+=1
            else:
                name2[core_name[i][1]]=1
            
    except Exception as e:
                      pass

# %%
count={}
for item in unique2.values():
    if item in count.keys():
        count[item]+=1
    else:
        count[item]=1
count
# Out:
# {1: 375,
#  2: 1,
#  4: 7,
#  5: 4,
#  6: 2,
#  10: 298,
#  11: 3,
#  12: 16,
#  13: 45,
#  14: 2,
#  18: 3,
#  19: 135,
#  20: 6,
#  21: 348,
#  26: 1,
#  114: 1}

# %%
final=[]
for item in unique2.items():
    if 10<=item[1]<=25:
        final.append(item)

# %%
dir2key={b:a+1 for a,b in enumerate(dir2.keys())}
dir2key["UNK"]=0
dir2key
# Out:
# {'.': 2,
#  'UNK': 0,
#  'applets': 29,
#  'applets_sh': 12,
#  'arch': 31,
#  'archival': 1,
#  'configs': 21,
#  'console-tools': 15,
#  'coreutils': 18,
#  'debianutils': 4,
#  'docs': 10,
#  'e2fsprogs': 13,
#  'editors': 28,
#  'examples': 11,
#  'findutils': 14,
#  'include': 33,
#  'init': 8,
#  'libbb': 6,
#  'libpwdgrp': 3,
#  'loginutils': 5,
#  'mailutils': 23,
#  'miscutils': 16,
#  'modutils': 25,
#  'networking': 32,
#  'printutils': 24,
#  'procps': 26,
#  'qemu_multiarch_testing': 30,
#  'runit': 9,
#  'scripts': 22,
#  'selinux': 17,
#  'shell': 7,
#  'sysklogd': 20,
#  'testsuite': 19,
#  'util-linux': 27}

# %%
key2dir={a+1:b for a,b in enumerate(dir2.keys())}
key2dir[0]="UNK"
key2dir
# Out:
# {0: 'UNK',
#  1: 'archival',
#  2: '.',
#  3: 'libpwdgrp',
#  4: 'debianutils',
#  5: 'loginutils',
#  6: 'libbb',
#  7: 'shell',
#  8: 'init',
#  9: 'runit',
#  10: 'docs',
#  11: 'examples',
#  12: 'applets_sh',
#  13: 'e2fsprogs',
#  14: 'findutils',
#  15: 'console-tools',
#  16: 'miscutils',
#  17: 'selinux',
#  18: 'coreutils',
#  19: 'testsuite',
#  20: 'sysklogd',
#  21: 'configs',
#  22: 'scripts',
#  23: 'mailutils',
#  24: 'printutils',
#  25: 'modutils',
#  26: 'procps',
#  27: 'util-linux',
#  28: 'editors',
#  29: 'applets',
#  30: 'qemu_multiarch_testing',
#  31: 'arch',
#  32: 'networking',
#  33: 'include'}

# %%
dir_seq=[]
for item in core_name:
    try:
        dir_seq.append(dir2key[item[0]])
    except Exception as e:
        dir_seq.append(0)
dir_seq
# Out:
# [22,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  14,
#  14,
#  14,
#  8,
#  8,
#  8,
#  8,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
# ...

# %%
for i in range(500):
    print(core_name[i])
# Out:
# ['scripts', 'Kbuild.include']
# ['miscutils', 'flash_lock_unlock.c']
# ['miscutils', 'devmem.c']
# ['miscutils', 'ubirename.c']
# ['miscutils', 'chrt.c']
# ['miscutils', 'strings.c']
# ['miscutils', 'readahead.c']
# ['miscutils', 'less.c']
# ['miscutils', 'runlevel.c']
# ['miscutils', 'beep.c']
# ['miscutils', 'inotifyd.c']
# ['miscutils', 'hdparm.c']
# ['miscutils', 'microcom.c']
# ['miscutils', 'timeout.c']
# ['miscutils', 'dc.c']
# ['miscutils', 'crontab.c']
# ['miscutils', 'man.c']
# ['miscutils', 'chat.c']
# ['miscutils', 'conspy.c']
# ['miscutils', 'flash_eraseall.c']
# ['miscutils', 'crond.c']
# ['miscutils', 'wall.c']
# ['miscutils', 'adjtimex.c']
# ['miscutils', 'mt.c']
# ['miscutils', 'taskset.c']
# ['miscutils', 'setsid.c']
# ['miscutils', 'makedevs.c']
# ['miscutils', 'fbsplash.c']
# ['miscutils', 'volname.c']
# ['miscutils', 'rx.c']
# ['miscutils', 'flashcp.c']
# ['miscutils', 'i2c_tools.c']
# ['miscutils', 'nandwrite.c']
# ['miscutils', 'last_fancy.c']
# ...

# %%
len(core_name)
# Out:
# 15909
