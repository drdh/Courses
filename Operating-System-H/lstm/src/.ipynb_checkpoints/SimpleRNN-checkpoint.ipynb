# %%
from keras.layers import Dense,Activation
from keras.layers.recurrent import SimpleRNN
from keras.models import Sequential
from keras.utils import plot_model
import numpy as np

# %%
fin=open("../data/alice_in_wonderland.txt","rb")
lines=[]
for line in fin:
    line=line.strip().lower()
    line=line.decode("ascii","ignore")
    if len(line)==0:
        continue
    lines.append(line)
fin.close()
text=" ".join(lines)

# %%
chars=set([c for c in text])
nb_chars=len(chars)
char2index=dict((c,i) for i,c in enumerate(chars))
index2char=dict((i,c) for i,c in enumerate(chars))

# %%
SEQLEN=10
STEP=1

input_chars=[]
label_chars=[]
for i in range(0,len(text)-SEQLEN,STEP):
    input_chars.append(text[i:i+SEQLEN])
    label_chars.append(text[i+SEQLEN])

# %%
X=np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y=np.zeros((len(input_chars),nb_chars),dtype=np.bool)
for i,input_char in enumerate(input_chars):
    for j,ch in enumerate(input_char):
        X[i,j,char2index[ch]]=1
    y[i,char2index[label_chars[i]]]=1

# %%
HIDDEN_SIZE=128
BATCH_SIZE=128
NUM_ITERATIONS=25
NUM_EPOCHS_PER_ITERATION=1
NUM_PREDS_PER_EPOCH=100

model=Sequential()
model.add(SimpleRNN(HIDDEN_SIZE,return_sequences=False,input_shape=(SEQLEN,nb_chars),unroll=True))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy",optimizer="rmsprop")

# %%
plot_model(model,to_file="SimpleRNN.png",show_shapes=True)

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" *50)
    print("Iteration #: %d"%(iteration))
    model.fit(X,y,batch_size=BATCH_SIZE,epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx=np.random.randint(len(input_chars))
    test_chars=input_chars[test_idx]
    print("Gerationg from seed: %s"%(test_chars))
    print(test_chars,end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest=np.zeros((1,SEQLEN,nb_chars))
        for i,ch in enumerate(test_chars):
            Xtest[0,i,char2index[ch]]=1
        pred=model.predict(Xtest,verbose=0)[0]
        ypred=index2char[np.argmax(pred)]
        print(ypred,end="")
        test_chars=test_chars[1:]+ypred
    print('\n')
# Out:
# ==================================================
# Iteration #: 0
# Epoch 1/1
# 158773/158773 [==============================] - 14s 86us/step - loss: 1.3824
# Gerationg from seed: arm-yard--
# arm-yard--while the readon in the words a mouse seemed to be a little think i seally a work and the readon in
#
# ==================================================
# Iteration #: 1
# Epoch 1/1
# 158773/158773 [==============================] - 11s 71us/step - loss: 1.3762
# Gerationg from seed: th its eye
# th its eyes and the queen and the queen and the queen and the queen and the queen and the queen and the queen
#
# ==================================================
# Iteration #: 2
# Epoch 1/1
# 158773/158773 [==============================] - 14s 91us/step - loss: 1.3712
# Gerationg from seed: ters remar
# ters remark. gutenberg-tm electronic works and states and seems to the took at the think the mouse of the thin
#
# ==================================================
# Iteration #: 3
# Epoch 1/1
# 158773/158773 [==============================] - 14s 85us/step - loss: 1.3668
# Gerationg from seed: i beg your
# i beg your all the foundation and the gryphon. the fact to herself, i was the footman in the foundation and th
#
# ==================================================
# Iteration #: 4
# Epoch 1/1
# 158773/158773 [==============================] - 14s 87us/step - loss: 1.3628
# Gerationg from seed: d impatien
# d impatient the queen and read the rent as she said to herself of the some with the trembled bottle so earent
#
# ==================================================
# Iteration #: 5
# Epoch 1/1
# 158773/158773 [==============================] - 12s 77us/step - loss: 1.3588
# Gerationg from seed: ssons! tho
# ssons! thought alice, and she said the dormouse, the king said the dormouse, the king said the dormouse, the k
#
# ==================================================
# Iteration #: 6
# Epoch 1/1
# 158773/158773 [==============================] - 14s 89us/step - loss: 1.3553
# Gerationg from seed:  it as you
#  it as you like the reast was so the mock turtle in the door of the project gutenberg-tm electronic works in t
#
# ==================================================
# Iteration #: 7
# Epoch 1/1
# 158773/158773 [==============================] - 15s 93us/step - loss: 1.3518
# Gerationg from seed: he stupide
# he stupided to the gryphon. the march hare well an off with a little thing to herself, i shell gone out of the
#
# ==================================================
# Iteration #: 8
# Epoch 1/1
# 158773/158773 [==============================] - 15s 94us/step - loss: 1.3478
# Gerationg from seed:  active li
#  active like the thing its all the thing its all the thing its all the thing its all the thing its all the thi
#
# ==================================================
# Iteration #: 9
# Epoch 1/1
# 158773/158773 [==============================] - 14s 90us/step - loss: 1.3442
# Gerationg from seed: r? alice g
# r? alice got to dear the caterpillar she had not down and she went on the works carted a reploces and she went
#
# ==================================================
# Iteration #: 10
# Epoch 1/1
# 158773/158773 [==============================] - 16s 100us/step - loss: 1.3417
# Gerationg from seed: erses to h
# erses to herself his had said to herself his had said to herself his had said to herself his had said to herse
#
# ==================================================
# Iteration #: 11
# Epoch 1/1
# 158773/158773 [==============================] - 15s 95us/step - loss: 1.3373
# Gerationg from seed: against th
# against the more the termed to secous get it off of the satter with the tarts me alood the caterpillar the cat
#
# ==================================================
# Iteration #: 12
# Epoch 1/1
# 158773/158773 [==============================] - 14s 91us/step - loss: 1.3348
# Gerationg from seed: sulky tone
# sulky tone, and she was a good and said to herself, and she was a good and said to herself, and she was a good
#
# ==================================================
# Iteration #: 13
# Epoch 1/1
# 158773/158773 [==============================] - 14s 85us/step - loss: 1.3322
# Gerationg from seed:  his throa
#  his throage a good a paid it was of the white rabbit of dears in a some a good a paid it was of the white rab
#
# ==================================================
# Iteration #: 14
# Epoch 1/1
# 158773/158773 [==============================] - 15s 92us/step - loss: 1.3290
# Gerationg from seed:  of this e
#  of this earself, and the mock turtle said to the gryphon. the footman it was a cant and the project gutenberg
#
# ==================================================
# Iteration #: 15
# Epoch 1/1
# 158773/158773 [==============================] - 15s 92us/step - loss: 1.3264
# Gerationg from seed: was nothin
# was nothing the tried once to the tone of the tried once to the tone of the tried once to the tone of the trie
#
# ==================================================
# Iteration #: 16
# Epoch 1/1
# 158773/158773 [==============================] - 14s 90us/step - loss: 1.3235
# Gerationg from seed: replied, s
# replied, said the king to herself the foundation and the queen the dormouse the king to herself the foundation
#
# ==================================================
# Iteration #: 17
# Epoch 1/1
# 158773/158773 [==============================] - 14s 89us/step - loss: 1.3221
# Gerationg from seed: gs, the ma
# gs, the march hare went on its the way a cat seems of the work or a cait works in a more shan in the look of t
#
# ==================================================
# Iteration #: 18
# Epoch 1/1
# 158773/158773 [==============================] - 12s 75us/step - loss: 1.3188
# Gerationg from seed: nd in his
# nd in his her from the project gutenberg-tm electronic works is the took a little statting to the thing a litt
#
# ==================================================
# Iteration #: 19
# Epoch 1/1
# 158773/158773 [==============================] - 13s 84us/step - loss: 1.3165
# Gerationg from seed: that depen
# that depenter, and she said to herself, and she said to herself, and she said to herself, and she said to hers
#
# ==================================================
# Iteration #: 20
# Epoch 1/1
# 158773/158773 [==============================] - 12s 77us/step - loss: 1.3146
# Gerationg from seed: d. is that
# d. is that a perchand but it was the sen them all the sen them all the sen them all the sen them all the sen t
#
# ==================================================
# Iteration #: 21
# Epoch 1/1
# 158773/158773 [==============================] - 13s 83us/step - loss: 1.3127
# Gerationg from seed: this be a
# this be a little thing it is a little thing it is a little thing it is a little thing it is a little thing it
#
# ==================================================
# Iteration #: 22
# Epoch 1/1
# 158773/158773 [==============================] - 13s 82us/step - loss: 1.3097
# Gerationg from seed:  and down
#  and down the caterpillar the baby what i should think the beginning to sinder that the mouse to the other the
#
# ==================================================
# Iteration #: 23
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.3083
# Gerationg from seed: to win, th
# to win, the dormouse she had got to the poor little shriek a right to the white rabbit the caterpillar. alice
#
# ==================================================
# Iteration #: 24
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.3066
# Gerationg from seed: , we went
# , we went on, what a moment the mock turtle read of the work or the work or the work or the work or the work o
